# %% [markdown]
# ### MNIST With Tensorflow and Tensor Board Visualization: Deep

# %%
import tensorflow as tf
from collections import namedtuple
from collections import deque
from sklearn.model_selection import train_test_split
import math
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
_ = plt.gray();

# %%
class MNIST(object):
    image = namedtuple("image", "data,normalized_data,w,h,size")
    label = namedtuple("label", "label,encoded,size")
    
    def __init__(self):
        self.train_image = self.read_image("train-images-idx3-ubyte")
        self.test_image = self.read_image("t10k-images-idx3-ubyte")
        self.train_label = self.read_label("train-labels-idx1-ubyte")
        self.test_label = self.read_label("t10k-labels-idx1-ubyte")
    
    def as_int(self, bytes):
        r = 0
        for b in bytes:
            r = (r << 8) | ord(b)
        return r
    
    def read_label(self, filename):
        with open(filename, "rb") as f:
            self.as_int(f.read(4)) # magic number
            size = self.as_int(f.read(4))
            digits = np.array(map(lambda x: ord(x), f.read(-1)))
            encoded = np.zeros([size, 10], dtype=np.float32)
            encoded[np.arange(size),digits] = 1
        return self.label(digits, encoded, size)
    
    def read_image(self, filename):
        with open(filename, "rb") as f:
            self.as_int(f.read(4)) # magic number
            size = self.as_int(f.read(4))
            w = self.as_int(f.read(4))
            h = self.as_int(f.read(4))
            data = np.array(map(lambda x: ord(x), f.read(-1)), dtype=np.float32).reshape(-1, w*h)
            norm = (data - data.mean(axis=0)) / (data.std(axis=0) + 1e-5)
        return self.image(data=data, normalized_data=norm, w=w, h=h, size=size)
    
    def _range_max(self, row, length):
        queue = deque()
        output = [0 for _ in xrange(len(row) - length + 1)]
        length -= 1
        for j, e in enumerate(row):
            while(len(queue) != 0 and queue[0][0] <= e):
                queue.popleft()
            queue.appendleft((e, j))
            if j < length:
                continue
            while(queue[-1][1] < (j - length)):
                queue.pop()
            
            output[j - length] = queue[-1][0]
            
        return output
        
    def _grid_max(self, arr2d, grid=(4, 4)):
        temp = np.array([self._range_max(arr1d, length=grid[0]) for arr1d in arr2d]).T
        return np.array([self._range_max(arr1d, length=grid[1]) for arr1d in temp]).T
    
    def augment_feature(self, data, grid=(5, 5)):
        """
        data is a 784xS size 2d array
        each row is reshaped 28x28 image
        lets calculate max in each grid
        """
        imsize = 28
        data_cube = data.reshape(data.shape[0], imsize, imsize)
        return np.array([self._grid_max(matrix, grid) for matrix in data_cube])

mnist = MNIST()

# %%
def next_batch(X, y, size):
    select = np.random.choice(X.shape[0], size)
    return (X[select,:], y[select,:])

# %%
tf.reset_default_graph()

def variable_summaries(var, name):
    with tf.name_scope('summaries/' + name):
        mean = tf.reduce_mean(var)
        tf.summary.scalar('mean', mean)
        with tf.name_scope('stddev'):
            stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
        tf.summary.scalar('stddev', stddev)
        tf.summary.scalar('max', tf.reduce_max(var))
        tf.summary.scalar('min', tf.reduce_min(var))
        tf.summary.histogram('histogram', var)
        

def dense_layer(name, input_dim, output_dim):
    with tf.variable_scope(name):
        W = tf.get_variable("W", shape=[input_dim, output_dim], 
                            dtype=tf.float64, initializer=tf.glorot_uniform_initializer())
        b = tf.get_variable("b", shape=[output_dim], dtype=tf.float64, initializer=tf.zeros_initializer())
        variable_summaries(W, name + "/weights")
        variable_summaries(b, name + "/biases")
        
    return W, b


def activation_layer(name, X, W, b, function=tf.nn.relu):
    with tf.variable_scope(name):
        y = tf.matmul(X, W, name="WX_plus_b") + b
        if function is not None:
            y_ = function(y, name="activation")
        else:
            y_ = y # identity
        variable_summaries(y_, name + "/activation")
        
    return y_


def dropout_layer(name, X, keep_prob):
    with tf.variable_scope(name):
        dropout = tf.nn.dropout(X, keep_prob=keep_prob, name="dropout")
    
    return dropout

#=======================================================================#

input_dim = 784
X = tf.placeholder(tf.float64, [None, input_dim])
keep_prob = tf.placeholder(dtype=tf.float64)

dropout1 = dropout_layer("Layer1", X, keep_prob)

L1_size = 512
W1, b1 = dense_layer("Layer1", input_dim, L1_size)
y1 = activation_layer("Layer1", dropout1, W1, b1)

L2_size = 256
W2, b2 = dense_layer("Layer2", L1_size, L2_size)
y2 = activation_layer("Layer2", y1, W2, b2)

L3_size = 64
W3, b3 = dense_layer("Layer3", L2_size, L3_size)
y3 = activation_layer("Layer3", y2, W3, b3)

output_dim = 10
W4, b4 = dense_layer("Layer4", L3_size, output_dim)
y4 = activation_layer("Layer4", y3, W4, b4)

y_ = tf.placeholder(tf.float64, [None, output_dim])

with tf.variable_scope("Loss"):
    cross_entropy = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(labels=y_, logits=y4), name="CrossEntropyLoss")

train_step = tf.train.GradientDescentOptimizer(learning_rate=0.04).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y4, 1), tf.argmax(y_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

tf.summary.scalar('cross_entropy', cross_entropy)
tf.summary.scalar('accuracy', accuracy)

merged = tf.summary.merge_all()

X_train, X_test, y_train, y_test = train_test_split(mnist.train_image.normalized_data, 
                                                    mnist.train_label.encoded, test_size=0.05)

with tf.Session() as sess:
    train_writer = tf.summary.FileWriter('train', sess.graph)
    tf.global_variables_initializer().run()
    batch_size = 100
    iterations = 20000
    step_size = 10000
    steps = batch_size * iterations / step_size
    for i in range(iterations):
        batch_xs, batch_ys = next_batch(X_train, y_train, batch_size)
        sess.run(train_step, feed_dict={X: batch_xs, y_: batch_ys, keep_prob:0.6})
        
        if (batch_size * i % step_size) == 0:
            batch_xs, batch_ys = X_test, y_test
            summary, acc_, loss_ = sess.run([merged, accuracy, cross_entropy], 
                                            feed_dict={X: batch_xs, y_: batch_ys, keep_prob:1.0})
            train_writer.add_summary(summary, global_step=i * batch_size / step_size)
            print "Step %d/%d, accuracy: %0.4f, loss=%0.6f" % (batch_size * i / step_size, steps, acc_, loss_)
        
    # Final accuracy on trained model
    predictions, accuracy_ = sess.run(
        [correct_prediction, accuracy], 
        feed_dict={X: mnist.test_image.normalized_data, y_: mnist.test_label.encoded, keep_prob: 1.0})
    
    print("Accuracy on test set: %0.4f" % accuracy_)
# Out:
# Step 0/200, accuracy: 0.1677, loss=2.328176
# Step 1/200, accuracy: 0.8450, loss=0.553453
# Step 2/200, accuracy: 0.9047, loss=0.335571
# Step 3/200, accuracy: 0.9183, loss=0.297216
# Step 4/200, accuracy: 0.9293, loss=0.254889
# Step 5/200, accuracy: 0.9320, loss=0.238650
# Step 6/200, accuracy: 0.9330, loss=0.229732
# Step 7/200, accuracy: 0.9403, loss=0.208746
# Step 8/200, accuracy: 0.9400, loss=0.211886
# Step 9/200, accuracy: 0.9440, loss=0.192773
# Step 10/200, accuracy: 0.9460, loss=0.183091
# Step 11/200, accuracy: 0.9507, loss=0.180362
# Step 12/200, accuracy: 0.9507, loss=0.176781
# Step 13/200, accuracy: 0.9530, loss=0.173635
# Step 14/200, accuracy: 0.9557, loss=0.168483
# Step 15/200, accuracy: 0.9537, loss=0.171493
# Step 16/200, accuracy: 0.9610, loss=0.165146
# Step 17/200, accuracy: 0.9597, loss=0.152185
# Step 18/200, accuracy: 0.9623, loss=0.139979
# Step 19/200, accuracy: 0.9600, loss=0.136212
# Step 20/200, accuracy: 0.9653, loss=0.141245
# Step 21/200, accuracy: 0.9620, loss=0.144431
# Step 22/200, accuracy: 0.9667, loss=0.134371
# Step 23/200, accuracy: 0.9653, loss=0.132426
# Step 24/200, accuracy: 0.9657, loss=0.133766
# Step 25/200, accuracy: 0.9657, loss=0.130221
# Step 26/200, accuracy: 0.9687, loss=0.125597
# Step 27/200, accuracy: 0.9653, loss=0.129074
# Step 28/200, accuracy: 0.9710, loss=0.124413
# Step 29/200, accuracy: 0.9680, loss=0.124041
# Step 30/200, accuracy: 0.9697, loss=0.121026
# Step 31/200, accuracy: 0.9707, loss=0.121324
# Step 32/200, accuracy: 0.9703, loss=0.119180
# Step 33/200, accuracy: 0.9707, loss=0.125844
# Step 34/200, accuracy: 0.9707, loss=0.118723
# Step 35/200, accuracy: 0.9720, loss=0.113070
# Step 36/200, accuracy: 0.9720, loss=0.111832
# Step 37/200, accuracy: 0.9740, loss=0.114267
# Step 38/200, accuracy: 0.9740, loss=0.109988
# Step 39/200, accuracy: 0.9750, loss=0.112719
# Step 40/200, accuracy: 0.9723, loss=0.110885
# Step 41/200, accuracy: 0.9730, loss=0.109801
# Step 42/200, accuracy: 0.9727, loss=0.110656
# Step 43/200, accuracy: 0.9707, loss=0.113005
# Step 44/200, accuracy: 0.9743, loss=0.109032
# Step 45/200, accuracy: 0.9757, loss=0.104471
# Step 46/200, accuracy: 0.9750, loss=0.101295
# Step 47/200, accuracy: 0.9727, loss=0.107025
# Step 48/200, accuracy: 0.9763, loss=0.102149
# Step 49/200, accuracy: 0.9770, loss=0.097278
# Step 50/200, accuracy: 0.9777, loss=0.096623
# Step 51/200, accuracy: 0.9767, loss=0.095818
# Step 52/200, accuracy: 0.9777, loss=0.097004
# Step 53/200, accuracy: 0.9763, loss=0.097042
# Step 54/200, accuracy: 0.9767, loss=0.095899
# Step 55/200, accuracy: 0.9743, loss=0.106660
# Step 56/200, accuracy: 0.9797, loss=0.099371
# Step 57/200, accuracy: 0.9773, loss=0.099967
# Step 58/200, accuracy: 0.9760, loss=0.100244
# Step 59/200, accuracy: 0.9780, loss=0.095773
# Step 60/200, accuracy: 0.9783, loss=0.091242
# Step 61/200, accuracy: 0.9770, loss=0.095789
# Step 62/200, accuracy: 0.9773, loss=0.094973
# Step 63/200, accuracy: 0.9783, loss=0.089593
# Step 64/200, accuracy: 0.9770, loss=0.097391
# Step 65/200, accuracy: 0.9790, loss=0.094796
# Step 66/200, accuracy: 0.9783, loss=0.097741
# Step 67/200, accuracy: 0.9797, loss=0.088848
# Step 68/200, accuracy: 0.9797, loss=0.088946
# Step 69/200, accuracy: 0.9803, loss=0.090071
# Step 70/200, accuracy: 0.9790, loss=0.089774
# Step 71/200, accuracy: 0.9797, loss=0.090816
# Step 72/200, accuracy: 0.9810, loss=0.086376
# Step 73/200, accuracy: 0.9820, loss=0.081059
# Step 74/200, accuracy: 0.9813, loss=0.086643
# Step 75/200, accuracy: 0.9807, loss=0.088895
# Step 76/200, accuracy: 0.9790, loss=0.090565
# Step 77/200, accuracy: 0.9793, loss=0.086466
# Step 78/200, accuracy: 0.9797, loss=0.085012
# Step 79/200, accuracy: 0.9807, loss=0.087089
# Step 80/200, accuracy: 0.9817, loss=0.084257
# Step 81/200, accuracy: 0.9807, loss=0.082924
# Step 82/200, accuracy: 0.9783, loss=0.091876
# Step 83/200, accuracy: 0.9803, loss=0.086829
# Step 84/200, accuracy: 0.9810, loss=0.084859
# Step 85/200, accuracy: 0.9810, loss=0.086060
# Step 86/200, accuracy: 0.9833, loss=0.082827
# Step 87/200, accuracy: 0.9767, loss=0.089353
# Step 88/200, accuracy: 0.9787, loss=0.088361
# Step 89/200, accuracy: 0.9797, loss=0.085877
# Step 90/200, accuracy: 0.9797, loss=0.083673
# Step 91/200, accuracy: 0.9800, loss=0.083471
# Step 92/200, accuracy: 0.9817, loss=0.080418
# Step 93/200, accuracy: 0.9800, loss=0.082935
# Step 94/200, accuracy: 0.9790, loss=0.086064
# Step 95/200, accuracy: 0.9810, loss=0.082271
# Step 96/200, accuracy: 0.9803, loss=0.079984
# Step 97/200, accuracy: 0.9783, loss=0.086283
# Step 98/200, accuracy: 0.9827, loss=0.080631
# Step 99/200, accuracy: 0.9783, loss=0.086072
# Step 100/200, accuracy: 0.9800, loss=0.086797
# Step 101/200, accuracy: 0.9813, loss=0.085930
# Step 102/200, accuracy: 0.9820, loss=0.081494
# Step 103/200, accuracy: 0.9803, loss=0.086141
# Step 104/200, accuracy: 0.9810, loss=0.081647
# Step 105/200, accuracy: 0.9803, loss=0.081327
# Step 106/200, accuracy: 0.9783, loss=0.087904
# Step 107/200, accuracy: 0.9803, loss=0.085399
# Step 108/200, accuracy: 0.9790, loss=0.082553
# Step 109/200, accuracy: 0.9810, loss=0.084268
# Step 110/200, accuracy: 0.9813, loss=0.080048
# Step 111/200, accuracy: 0.9827, loss=0.078883
# Step 112/200, accuracy: 0.9820, loss=0.078354
# Step 113/200, accuracy: 0.9827, loss=0.084831
# Step 114/200, accuracy: 0.9833, loss=0.079829
# Step 115/200, accuracy: 0.9803, loss=0.083249
# Step 116/200, accuracy: 0.9800, loss=0.079080
# Step 117/200, accuracy: 0.9807, loss=0.080780
# Step 118/200, accuracy: 0.9823, loss=0.078316
# Step 119/200, accuracy: 0.9823, loss=0.076877
# Step 120/200, accuracy: 0.9813, loss=0.082174
# Step 121/200, accuracy: 0.9807, loss=0.080285
# Step 122/200, accuracy: 0.9823, loss=0.080189
# Step 123/200, accuracy: 0.9817, loss=0.081060
# Step 124/200, accuracy: 0.9850, loss=0.082215
# Step 125/200, accuracy: 0.9813, loss=0.080619
# Step 126/200, accuracy: 0.9810, loss=0.083191
# Step 127/200, accuracy: 0.9823, loss=0.077723
# Step 128/200, accuracy: 0.9823, loss=0.079947
# Step 129/200, accuracy: 0.9827, loss=0.076644
# Step 130/200, accuracy: 0.9827, loss=0.079038
# Step 131/200, accuracy: 0.9830, loss=0.079508
# Step 132/200, accuracy: 0.9820, loss=0.081297
# Step 133/200, accuracy: 0.9820, loss=0.079036
# Step 134/200, accuracy: 0.9827, loss=0.084531
# Step 135/200, accuracy: 0.9810, loss=0.082329
# Step 136/200, accuracy: 0.9840, loss=0.076450
# Step 137/200, accuracy: 0.9833, loss=0.078260
# Step 138/200, accuracy: 0.9833, loss=0.076955
# Step 139/200, accuracy: 0.9830, loss=0.078399
# Step 140/200, accuracy: 0.9823, loss=0.085054
# Step 141/200, accuracy: 0.9847, loss=0.082149
# Step 142/200, accuracy: 0.9830, loss=0.082010
# Step 143/200, accuracy: 0.9830, loss=0.079706
# Step 144/200, accuracy: 0.9807, loss=0.081673
# Step 145/200, accuracy: 0.9800, loss=0.083533
# Step 146/200, accuracy: 0.9803, loss=0.084408
# Step 147/200, accuracy: 0.9850, loss=0.077469
# Step 148/200, accuracy: 0.9833, loss=0.082312
# Step 149/200, accuracy: 0.9817, loss=0.083528
# Step 150/200, accuracy: 0.9817, loss=0.076622
# Step 151/200, accuracy: 0.9810, loss=0.078966
# Step 152/200, accuracy: 0.9810, loss=0.083996
# Step 153/200, accuracy: 0.9820, loss=0.083932
# Step 154/200, accuracy: 0.9817, loss=0.083071
# Step 155/200, accuracy: 0.9823, loss=0.080524
# Step 156/200, accuracy: 0.9820, loss=0.076913
# Step 157/200, accuracy: 0.9837, loss=0.080190
# Step 158/200, accuracy: 0.9840, loss=0.080966
# Step 159/200, accuracy: 0.9807, loss=0.082871
# Step 160/200, accuracy: 0.9823, loss=0.078627
# Step 161/200, accuracy: 0.9817, loss=0.081631
# Step 162/200, accuracy: 0.9827, loss=0.081439
# Step 163/200, accuracy: 0.9827, loss=0.076904
# Step 164/200, accuracy: 0.9857, loss=0.078852
# Step 165/200, accuracy: 0.9830, loss=0.082236
# Step 166/200, accuracy: 0.9813, loss=0.083839
# Step 167/200, accuracy: 0.9833, loss=0.081459
# Step 168/200, accuracy: 0.9820, loss=0.082821
# Step 169/200, accuracy: 0.9847, loss=0.076792
# Step 170/200, accuracy: 0.9830, loss=0.077329
# Step 171/200, accuracy: 0.9830, loss=0.081609
# Step 172/200, accuracy: 0.9827, loss=0.079055
# Step 173/200, accuracy: 0.9807, loss=0.079721
# Step 174/200, accuracy: 0.9850, loss=0.074103
# Step 175/200, accuracy: 0.9827, loss=0.078639
# Step 176/200, accuracy: 0.9817, loss=0.079585
# Step 177/200, accuracy: 0.9820, loss=0.075466
# Step 178/200, accuracy: 0.9837, loss=0.076376
# Step 179/200, accuracy: 0.9813, loss=0.081669
# Step 180/200, accuracy: 0.9820, loss=0.076905
# Step 181/200, accuracy: 0.9830, loss=0.076265
# Step 182/200, accuracy: 0.9830, loss=0.077607
# Step 183/200, accuracy: 0.9807, loss=0.076633
# Step 184/200, accuracy: 0.9843, loss=0.072680
# Step 185/200, accuracy: 0.9823, loss=0.081301
# Step 186/200, accuracy: 0.9823, loss=0.077613
# Step 187/200, accuracy: 0.9827, loss=0.076536
# Step 188/200, accuracy: 0.9827, loss=0.079168
# Step 189/200, accuracy: 0.9807, loss=0.084000
# Step 190/200, accuracy: 0.9807, loss=0.082709
# Step 191/200, accuracy: 0.9817, loss=0.083290
# Step 192/200, accuracy: 0.9817, loss=0.081658
# Step 193/200, accuracy: 0.9800, loss=0.083565
# Step 194/200, accuracy: 0.9817, loss=0.087800
# Step 195/200, accuracy: 0.9817, loss=0.085859
# Step 196/200, accuracy: 0.9820, loss=0.084782
# Step 197/200, accuracy: 0.9830, loss=0.076238
# Step 198/200, accuracy: 0.9847, loss=0.073593
# Step 199/200, accuracy: 0.9837, loss=0.080331
# Accuracy on test set: 0.9818

# %%
missclassified_images = mnist.test_image.data[~predictions]
print (missclassified_images.shape)
# Out:
# (182, 784)

# %%
fig = plt.figure(figsize=(14,14))
plt.title("Missclassified Digits")
plt.axis("off")
for i, row in enumerate(missclassified_images):
    fig.add_subplot(14, 14, i+1).axis("off")
    plt.imshow(row.reshape(28, 28))
